# %%
# !pip install biopython pandas numpy matplotlib seaborn scipy networkx

# %%
# Cell 2: Import the module
from phylogenetic_utils import PhylogeneticAnalyzer, run_quick_analysis, plot_just_dendrogram, plot_just_heatmap, plot_just_network

# Cell 3: Quick complete analysis
print("🧬 Running complete phylogenetic analysis...")
analyzer, results = run_quick_analysis('../dataset/Sample 5 Proteins.fasta')

# Cell 4: Access results
print("\n📊 Analysis Results:")
print(f"Distance matrix shape: {results['distance_matrix'].shape}")
print(f"Available results: {list(results.keys())}")

# Display distance matrix
results['distance_matrix']

# Cell 5: Individual plots  

# Just dendrogram
# analyzer2 = plot_just_dendrogram('../dataset/Sample 5 Proteins.fasta')

# Just heatmap  
# analyzer3 = plot_just_heatmap('../dataset/Sample 5 Proteins.fasta')

# Just network tree
# analyzer4 = plot_just_network('../dataset/Sample 5 Proteins.fasta')

# Cell 6: Custom analysis with specific methods
print("\n🔬 Custom analysis example:")
custom_analyzer = PhylogeneticAnalyzer('../dataset/Sample 5 Proteins.fasta')

# Calculate distances with different method
custom_analyzer.calculate_pairwise_distances(method='hamming')

# Plot specific visualizations
custom_analyzer.plot_distance_heatmap()
custom_analyzer.plot_dendrogram()

# Cell 7: Compare multiple methods
print("\n⚖️ Comparing different distance methods:")
custom_analyzer.compare_methods()

# Cell 8: Export results (optional)
# custom_analyzer.export_tree_newick('my_tree.nwk')

print("✅ Analysis complete!")

# %%
# Cell 2: Import the module
from phylogenetic_utils import PhylogeneticAnalyzer, run_quick_analysis, plot_just_dendrogram, plot_just_heatmap, plot_just_network

# Cell 3: Quick complete analysis
print("🧬 Running complete phylogenetic analysis...")
analyzer, results = run_quick_analysis('dataset/NR_sample_5proteins.fasta')

# Cell 4: Access results
print("\n📊 Analysis Results:")
print(f"Distance matrix shape: {results['distance_matrix'].shape}")
print(f"Available results: {list(results.keys())}")

# Display distance matrix
results['distance_matrix']

# Cell 5: Individual plots (if you want to run them separately)

# Just dendrogram
# analyzer2 = plot_just_dendrogram('dataset/NR_sample_5proteins.fasta')

# Just heatmap  
# analyzer3 = plot_just_heatmap('dataset/NR_sample_5proteins.fasta')

# Just network tree
# analyzer4 = plot_just_network('dataset/NR_sample_5proteins.fasta')

# Cell 6: Custom analysis with specific methods
print("\n🔬 Custom analysis example:")
custom_analyzer = PhylogeneticAnalyzer('dataset/NR_sample_5proteins.fasta')

# Calculate distances with different method
custom_analyzer.calculate_pairwise_distances(method='hamming')

# Plot specific visualizations
custom_analyzer.plot_distance_heatmap()
custom_analyzer.plot_dendrogram()

# Cell 7: Compare multiple methods
print("\n⚖️ Comparing different distance methods:")
custom_analyzer.compare_methods()

# Cell 8: Export results (optional)
# custom_analyzer.export_tree_newick('my_tree.nwk')

print("✅ Analysis complete!")
# Out:
# 🧬 Running complete phylogenetic analysis...
# Loading sequences...
# Loaded 5 sequences
#   1. NP_000508.1 (142 aa)
#   2. NP_001001.1 (249 aa)
#   3. NP_001002.1 (194 aa)
#   4. NP_001003.1 (208 aa)
#   5. NP_001009.1 (145 aa)
# ...
# COMPLETE PHYLOGENETIC ANALYSIS
# ...
#
# Calculating pairwise distances using kmer method...
# Distance Matrix:
#              NP_000508.1  NP_001001.1  NP_001002.1  NP_001003.1  NP_001009.1
# NP_000508.1        0.000        0.945        0.977        0.983        1.000
# NP_001001.1        0.945        0.000        0.933        0.887        0.961
# NP_001002.1        0.977        0.933        0.000        0.939        0.971
# NP_001003.1        0.983        0.887        0.939        0.000        0.951
# NP_001009.1        1.000        0.961        0.971        0.951        0.000
#
# Plotting distance heatmap...
# Plotting dendrogram...
# Plotting network tree...
# Building Neighbor-Joining tree...
# Trying alternative distance matrix format...
# ...
